# %% [markdown]
# # List and Tuples <hr style="border:2.5px solid rgba(66, 78, 238, 1)"></hr>

# %% [markdown]
# <b>Tracy Renz C. Faura</b>
# <br>BSECE Student

# %% [markdown]
# # Creating a List

# %%
numbers = [1,2,3,4,5]

# %%
numbers = [1,2,3,4,5]
type(numbers)
# Out:
# list

# %%
fruits=['hatdo', 'pinyapol','hatdogging']
fruits
# Out:
# ['hatdo', 'pinyapol', 'hatdogging']

# %%
mixed_list = [10, ' hatdog' , 'true' , 2.5]
mixed_list
# Out:
# [10, ' hatdog', 'true', 2.5]

# %% [markdown]
# # INDEXING

# %%
fruits = ['eleven', 'seven', 'nine hundred']

fruits[0]
fruits[-1]
# Out:
# 'nine hundred'

# %% [markdown]
# # Modifying of Elements

# %%
tools = ['microphone', 'soldering iron', 'solder wick', 
         'multimeter', 'oscilloscope']
tools[0]= 'solder stand'
print(tools)
# Out:
# ['solder stand', 'soldering iron', 'solder wick', 'multimeter', 'oscilloscope']

# %% [markdown]
# # ADDING OF ELEMENTS

# %%
numbers = [1,2,3,4,5]
numbers.count
# Out:
# <function list.count(value, /)>

# %% [markdown]
# # SORT AND SORTED

# %%
hatdog = [2,3,1,4,5]
sorted(hatdog)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # SLICING

# %%
char = ['hatdog', 'mayonaise']
len(char)
# Out:
# 2

# %% [markdown]
# # TUPLE

# %%
MY_TUPLE = [1,2,3,4,5]
MY_TUPLE
# Out:
# [1, 2, 3, 4, 5]
