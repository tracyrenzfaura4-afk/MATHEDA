# %% [markdown]
# # PANDA BASICS

# %%
# %pip install pandas --upgrade
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.1 MB 2.1 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/11.1 MB 2.8 MB/s eta 0:00:04
#    --------------- ------------------------ 4.2/11.1 MB 4.9 MB/s eta 0:00:02
#    ------------------------------ --------- 8.4/11.1 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 9.2 MB/s  0:00:01
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# ...
#
#    ---------------------------------------- 0/3 [pytz]
# ...

# %%
# imports and packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # DATA FRAME

# %%
# imports and packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# creating dictionary
data = {
    "Name": ['Henry', 'Owen', 'Ada'],
    "Age": [22, 35, 58],
    "Sex": ['M', 'M', 'F']
}

# creating dataframe from dictionary
df = pd.DataFrame(data)
df
# Out:
#     Name  Age Sex
# 0  Henry   22   M
# 1   Owen   35   M
# 2    Ada   58   F

# %% [markdown]
# # SERIES

# %%
# selecting 'Name' column
df['Name']

# selecting 'Age' column
df['Age']

# selecting 'Sex' column
df['Sex']
# Out:
# 0    M
# 1    M
# 2    F
# Name: Sex, dtype: object

# %% [markdown]
# # DESCRIPTIVE STATISTICS

# %%
# Jaguar vs Panther
resistance = np.array([
    [10.8, 9.1, 9.3, 9.8, 10.5, 10.4, 9.5, 11, 10.4, 3, 9.8],
    [10.1, 11, 9.1, 20, 9.2, 10.8, 9.9, 9.2, 9.1, 9.1, np.nan]
]).T
resistance

# Creating DataFrame from numpy array
df = pd.DataFrame(resistance, columns=['Jaguar', 'Panther'])
df

# Summary of dataframe
df.info()

# Check object type
type(df)

# Summary of statistics
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Jaguar   11 non-null     float64
#  1   Panther  10 non-null     float64
# dtypes: float64(2)
# memory usage: 308.0 bytes
#           Jaguar    Panther
# count  11.000000  10.000000
# mean    9.418182  10.750000
# std     2.216221   3.329081
# min     3.000000   9.100000
# 25%     9.400000   9.125000
# 50%     9.800000   9.550000
# 75%    10.450000  10.625000
# max    11.000000  20.000000

# %%
# imports and packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# creating dictionary
data = {
    "Name":['Henry', 'Owen', 'Ada'],
    "Age":[22,35,58],
    "Sex":['M','M','F']
}

# creating dataframe from dictionary
df = pd.DataFrame(data)
df

# selecting 'Name' column
df['Name']

# selecting 'Age' column
df['Age']

# selecting 'Sex' column
df['Sex']

# Jaguar vs Panther
resistance = np.array([
    [10.8,9.1,9.3,9.8,10.5,10.4,9.5,11,10.4,3,9.8],
    [10.1,11,9.1,20,9.2,10.8,9.9,9.2,9.1,9.1,np.nan]
]).T
resistance

# Creating DataFrame from numpy array
df = pd.DataFrame(resistance,columns=['Jaguar','Panther'])
df

# Summary of dataframe
df.info()

type(df)

# Summary of statistics
df.describe()

# Median
jag_median = df['Jaguar'].median()
pan_median = df['Panther'].median()

print(f'Jaguar Median = {jag_median:.2f} ohms')
print(f'Panther Median = {pan_median:.2f} ohms')

# Mode
jag_mode = df['Jaguar'].mode()
pan_mode = df['Panther'].mode()

jag_mode

jag_mode.info()

type(jag_mode)

print('Jaguar Mode:')

for i in jag_mode:
    print(i)

print('Panther Mode:')

for i in pan_mode:
    print(i)

# Jaguar IQR
Q1 = df['Jaguar'].quantile(0.25)
Q3 = df['Jaguar'].quantile(0.75)

print(f'Jaguar IQR = {Q3-Q1:.2f} ohms')

# Panther IQR
Q1 = df['Panther'].quantile(0.25)
Q3 = df['Panther'].quantile(0.75)

print(f'Panther IQR = {Q3-Q1:.2f} ohms')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Jaguar   11 non-null     float64
#  1   Panther  10 non-null     float64
# dtypes: float64(2)
# memory usage: 308.0 bytes
# Jaguar Median = 9.80 ohms
# Panther Median = 9.55 ohms
# <class 'pandas.core.series.Series'>
# RangeIndex: 2 entries, 0 to 1
# Series name: Jaguar
# Non-Null Count  Dtype
# --------------  -----
# 2 non-null      float64
# dtypes: float64(1)
# memory usage: 148.0 bytes
# Jaguar Mode:
# 9.8
# 10.4
# Panther Mode:
# 9.1
# Jaguar IQR = 1.05 ohms
# Panther IQR = 1.50 ohms

# %% [markdown]
# # BAR CHART

# %%
jag_mean = df['Jaguar'].mean()
pan_mean = df['Panther'].mean()

plt.figure(figsize=(7,4))
bars = plt.bar(['Jaguar','Panther'],[jag_mean,pan_mean],
               color='#126782')
plt.title('Average Resistance by Machine')
plt.ylabel('Resistance (ohms)')

# bar labels
plt.bar_label(bars,padding=3)
plt.margins(y=0.1)
plt.show()
