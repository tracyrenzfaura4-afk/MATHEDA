# %% [markdown]
# # FOR LOOP <hr style="border:2.5px solid rgba(31, 213, 70, 1)"></hr>

# %%
fruits = ['banana', 'apple', 'orange']

for fruits in fruits:
        print(f'I like {fruits}')
# Out:
# I like banana
# I like apple
# I like orange

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # Iliterating over a Dictionary

# %%
user = {"name": "Alice", "role": "Engineer", "id": 42}

for key in user:
    print(key)

for val in user.values():
    print(val)
# Out:
# name
# role
# id
# Alice
# Engineer
# 42
